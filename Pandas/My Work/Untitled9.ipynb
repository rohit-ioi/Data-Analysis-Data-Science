# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host= 'localhost', user = 'root', passwd = "1AJ23bm@69")

# %%
mydb

# %%
cursor = mydb.cursor()
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('pwioi',),
#  ('sys',)]

# %%
cursor = mydb.cursor()

# %%
cursor.execute('insert into pwioi.abc values(1003, "Amulya", 45)')

# %% [markdown]
# mydb.commit()

# %%
mydb.commit()

# %%
cursor.execute("select * from  pwioi.abc")

# %%
cursor.fetchall()
# Out:
# [(1001, 'AMAN', 79),
#  (1002, 'BHAVIK', 99),
#  (1003, 'Chinmoy', 57),
#  (1004, 'Daksh', 45),
#  (1005, 'Rohit', 98),
#  (1006, 'Sumit', 78),
#  (1012, 'Aditya', 76),
#  (1013, 'Suraj', 86),
#  (1003, 'Amulya', 45)]

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 3A39-5137
#
#  Directory of C:\Users\trkro\Downloads
#
# 05-03-2024  12:51    <DIR>          .
# 25-02-2024  21:42    <DIR>          ..
# 05-03-2024  12:13    <DIR>          .ipynb_checkpoints
# 26-01-2024  18:54         4,787,175 156A0722.JPG
# 31-01-2024  14:08         1,052,939 23035010336 (1).pdf
# 23-10-2023  19:48         1,052,939 23035010336.pdf
# 04-03-2024  16:55        13,632,841 6568179250c244fbec73aaf4.pdf
# 29-02-2024  13:30        37,732,975 65c7381571938981dff646db (1).pdf
# 29-02-2024  13:27        37,732,975 65c7381571938981dff646db.pdf
# 18-01-2024  11:49     1,095,571,496 Anaconda3-2023.09-0-Windows-x86_64.exe
# 08-11-2023  01:29         3,023,657 Art+of+listening+(3).pdf
# 11-12-2023  23:51            74,555 b-BC_QmVR5WGhpczsvQ-3A_2d10395731064dd2abe3afb9c88c6ea1_Week-6-Lesson-1.xlsx
# ...

# %%
data = open("sample-1.txt")
read_content = data.read()
print(read_content)
# Out:
# ï»¿Sample Document
#
# Fusce convallis metus id felis luctus adipiscing. Pellentesque egestas, neque sit amet convallis pulvinar, justo nulla eleifend augue, ac auctor orci leo non est. Fusce vel dui. Sed augue ipsum, egestas nec, vestibulum et, malesuada adipiscing, dui. Phasellus viverra nulla ut metus varius laoreet.
#
#
# Nulla facilisi. Phasellus accumsan cursus velit. Curabitur at lacus ac velit ornare lobortis. Maecenas vestibulum mollis diam. Phasellus blandit leo ut odio.
#
#
# Praesent ac massa at ligula laoreet iaculis. Pellentesque dapibus hendrerit tortor. Nam commodo suscipit quam. Sed a libero. Nullam nulla eros, ultricies sit amet, nonummy id, imperdiet feugiat, pede.
#
#
# Pellentesque egestas, neque sit amet convallis pulvinar, justo nulla eleifend augue, ac auctor orci leo non est. Curabitur ullamcorper ultricies nisi. Pellentesque posuere. Fusce fermentum. Morbi vestibulum volutpat enim.
#
#
# ...

# %%
data = open('sample-1.txt', 'w')
data.write('hi from pwioi.\n')
data.write('data science for beginners\n')
# Out:
# 27

# %%
data = open("sample-1.txt")

# %%
# read the file content
read_content = data.read()
print(read_content)
# Out:
# hi from pwioi.
# data science for beginners

# %%
data = open("sample-1.txt", "r")

# %%
read_content = data.read()
print(read_content)
# Out:
# hi from pwioi.
# data science for beginners

# %%
data.close()

# %%
with open("sample-1.txt", "r") as data:
    read_content = data.read()
    print(read_content)
# Out:
# hi from pwioi.
# data science for beginners

# %%
import csv
with open('glass.data' , 'r') as f :
    glass_data = csv.reader(f , delimiter = '\n')
    for i in glass_data:
        print(i[0])
# Out:
# 1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1
# 2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1
# 3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1
# 4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1
# 5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1
# 6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1
# 7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1
# 8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1
# 9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1
# 10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1
# 11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1
# 12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1
# 13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1
# 14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1
# 15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1
# 16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1
# 17,1.51784,12.68,3.67,1.16,73.11,0.61,8.70,0.00,0.00,1
# ...

# %%
import csv
with open('glass.data' , 'r') as f :
    glass_data = csv.reader(f , delimiter = '\n')
    for i in glass_data:
        print(i)
# Out:
# ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1']
# ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1']
# ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1']
# ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1']
# ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1']
# ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1']
# ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1']
# ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1']
# ['9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1']
# ['10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1']
# ['11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1']
# ['12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1']
# ['13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1']
# ['14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1']
# ['15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1']
# ['16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1']
# ...

# %%
import csv
with open('glass.data' , 'r') as f :
    glass_data = csv.reader(f , delimiter = '\n')
    print(list(glass_data))
# Out:
# [['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1'], ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1'], ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1'], ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1'], ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1'], ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1'], ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1'], ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1'], ['9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1'], ['10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1'], ['11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1'], ['12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1'], ['13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1'], ['14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1'], ['15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1'], ['16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1'], ['17,1.51784,12.68,3.67,1.16,73.11,0.61,8.70,0
# ...

# %%
print(glass_data)

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host = 'localhost',user = 'root' ,passwd = "1AJ23bm@69" )

# %%
mydb

# %%
cursor = mydb.cursor()

# %%
cursor.execute("show databases")
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 cursor.execute("show databases")
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\cursor_cext.py:347, in CMySQLCursor.execute(self, operation, params, multi)
#     345 except (ProgrammingError, ReferenceError) as err:
#     346     raise ProgrammingError("Cursor is not connected", 2055) from err
# --> 347 self._cnx.handle_unread_result()
#     349 stmt = b""
#     350 self.reset()
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:990, in CMySQLConnection.handle_unread_result(self, prepared)
#     988     self.consume_results()
#     989 elif unread_result:
# --> 990     raise InternalError("Unread result found")
#
# InternalError: Unread result found
