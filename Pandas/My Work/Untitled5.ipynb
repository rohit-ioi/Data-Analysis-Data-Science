# %%
import pandas as pd

# %%
df = pd.read_csv('cardekho_dataset.csv')

# %%
df
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# ...

# %%
def1 = pd.read_json('unece.json')
def1
# Out:
#         Country  Year  Area (square kilometres)  Total population  \
# 0       Albania  2000                   28748.0         3401198.0
# 1       Albania  2001                   28748.0         3073734.0
# 2       Albania  2002                   28748.0         3093465.0
# 3       Albania  2003                   28748.0         3111162.0
# 4       Albania  2004                   28748.0         3127264.0
# ..          ...   ...                       ...               ...
# 879  Uzbekistan  2012                  447400.0        29774448.0
# 880  Uzbekistan  2013                  447400.0        30243172.0
# 881  Uzbekistan  2014                  447400.0        30757669.0
# 882  Uzbekistan  2015                  447400.0        31298929.0
# 883  Uzbekistan  2016                  447400.0               NaN
#
#      Population density, pers. per sq. km  Population aged 0-14, male  \
# 0                               118.31077                    564851.0
# ...

# %%
def2 = pd.read_excel('titanic_modified_NA.xlsx')
def2
# Out:
#      PassengerId Survived  Pclass  \
# 0              1        0       3
# 1              2        1       1
# 2              3        1       3
# 3              4        1       1
# 4              5        0       3
# ..           ...      ...     ...
# 886          887        0       2
# 887          888        1       1
# 888          889        0       3
# 889          890        1       1
# 890          891        0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def3 = pd.read_csv("https://raw.githubusercontent.com/pwskills123/pwioidatascience/main/pandas/cardekho_dataset.csv")
def3
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize
def5 = pd.read_html('https://en.wikipedia.org/wiki/Animal')
def5
# Out:
# [   Animals Temporal range: Cryogenian – present, 665–0 Ma Pha. Proterozoic Archean Had.  \
#  0                                                 NaN
#  1                           Scientific classification
#  2                                             Domain:
#  3                                              Clade:
#  4                                              Clade:
#  5                                         (unranked):
#  6                                         (unranked):
#  7                                         (unranked):
#  8                                            Kingdom:
#  9                                        Subdivisions
#  10  Bilateria (~30 phyla) Cnidaria Ctenophora Plac...
#  11                                           Synonyms
#  12  Metazoa Haeckel 1874[1] Choanoblastaea Nielsen...
#
#     Animals Temporal range: Cryogenian – present, 665–0 Ma Pha. Proterozoic Archean Had..1
#  0                                                 NaN
# ...

# %%
def5[1]
# Out:
#                                                Phylum  \
# 0                                          Arthropoda
# 1                                            Mollusca
# 2                                            Chordata
# 3                                     Platyhelminthes
# 4                                            Nematoda
# 5                                            Annelida
# 6                                            Cnidaria
# 7                                            Porifera
# 8                                       Echinodermata
# 9                                             Bryozoa
# 10                                           Rotifera
# 11                                           Nemertea
# 12                                         Tardigrada
# 13  Total number of described extant species as of...
#
#                                               Example  \
# 0                                                 NaN
# ...

# %%
covid = pd.read_csv('COVID19Cases.csv')
covid
# Out:
# C:\Users\trkro\AppData\Local\Temp\ipykernel_9608\641311957.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   covid = pd.read_csv('COVID19Cases.csv')
#         Case_Type  People_Total_Tested_Count  Cases  Difference       Date  \
# 0       Confirmed                        NaN      6           0  5/22/2020
# 1       Confirmed                        NaN      0           0   2/3/2020
# 2          Deaths                        NaN      0           0   3/1/2020
# 3       Confirmed                        NaN     23           0  4/21/2020
# 4          Deaths                        NaN     56           0  5/11/2020
# ...           ...                        ...    ...         ...        ...
# 950665     Deaths                        NaN      0           0  1/22/2020
# 950666  Confirmed                        NaN      0           0  1/22/2020
# 950667     Deaths                        NaN      0           0  1/22/2020
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 ext = covid.loc[[0,1,2,3,4,5], 'Case_Type', 'Cases', 'Date']
#       2 ext
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1283, in _LocIndexer._getitem_tuple(self, tup)
#    1280     return self._getitem_lowerdim(tup)
#    1282 # no multi-index, so validate all of the indexers
# -> 1283 tup = self._validate_tuple_indexer(tup)
#    1285 # ugly hack for GH #836
# ...
