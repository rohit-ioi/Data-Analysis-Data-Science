# %%
import pandas as pd
s = pd.Series([1,2,3,4], index = ["a", "b", "c", "d"])
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
import numpy as np

# %%
li = [1,2,3]
type(li)
# Out:
# list

# %%
a1 = pd.Series(np.arange(4),
              index = ["a", "c", "d", "e"])
a1
# Out:
# a    0
# c    1
# d    2
# e    3
# dtype: int32

# %%
a2 = pd.Series(np.arange(5),
              index = ["a", "b", "c", "d", "e"])
a2
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int32

# %%
df=pd.DataFrame(
    np.arange(12).reshape(3,4),
    index=["two","one","three"],
    columns=["d","a","b","c"])
df
# Out:
#        d  a   b   c
# two    0  1   2   3
# one    4  5   6   7
# three  8  9  10  11

# %%
df.drop('two')
df
# Out:
#        d  a   b   c
# two    0  1   2   3
# one    4  5   6   7
# three  8  9  10  11

# %%
df.mean(1)
# Out:
# two      1.5
# one      5.5
# three    9.5
# dtype: float64

# %%
df.mean(0)
# Out:
# d    4.0
# a    5.0
# b    6.0
# c    7.0
# dtype: float64

# %%
df
# Out:
#        d  a   b   c
# two    0  1   2   3
# one    4  5   6   7
# three  8  9  10  11

# %%
df1=pd.DataFrame(
    np.arange(6).reshape(2,3),
    columns=list("ABC"),
    index=["Tim","Tom"])
df2=pd.DataFrame(
    np.arange(9).reshape(3,3),
    columns=list("ACD"),
    index=["Tim","Kate","Tom"])
df1
# Out:
#      A  B  C
# Tim  0  1  2
# Tom  3  4  5

# %%
df2
# Out:
#       A  C  D
# Tim   0  1  2
# Kate  3  4  5
# Tom   6  7  8

# %%
df1 + df2
# Out:
#         A   B     C   D
# Kate  NaN NaN   NaN NaN
# Tim   0.0 NaN   3.0 NaN
# Tom   9.0 NaN  12.0 NaN

# %%
df1.add(df2,fill_value=0)
# Out:
#         A    B     C    D
# Kate  3.0  NaN   4.0  5.0
# Tim   0.0  1.0   3.0  2.0
# Tom   9.0  4.0  12.0  8.0

# %%
df=pd.DataFrame(
    np.arange(12).reshape(3,4),
    index=["two","one","three"],
    columns=["d","a","b","c"])
df
# Out:
#        d  a   b   c
# two    0  1   2   3
# one    4  5   6   7
# three  8  9  10  11

# %%
df.drop('two')
# Out:
#        d  a   b   c
# one    4  5   6   7
# three  8  9  10  11

# %%
df.drop('b', axis = 1)
# Out:
#        d  a   c
# two    0  1   3
# one    4  5   7
# three  8  9  11

# %%
import numpy as pd
import pandas as pd

# %%
cs = pd.DataFrame(np.arange(9).reshape(3,3),
                index=["a","c","d"],
                columns=["Tim","Tom","Kate"])
cs
# Out:
#    Tim  Tom  Kate
# a    0    1     2
# c    3    4     5
# d    6    7     8

# %%
names = ["Tom", "Tim", "Kate"]
cs.reindex(columns=names)
# Out:
#    Tom  Tim  Kate
# a    1    0     2
# c    4    3     5
# d    7    6     8

# %%
cs
# Out:
#    Tim  Tom  Kate
# a    0    1     2
# c    3    4     5
# d    6    7     8

# %%
df=pd.DataFrame(
    np.arange(12).reshape(3,4),
    index=["two","one","three"],
    columns=["d","a","b","c"])
df
# Out:
#        d  a   b   c
# two    0  1   2   3
# one    4  5   6   7
# three  8  9  10  11

# %%
df1=pd.DataFrame(
    np.arange(6).reshape(2,3),
    columns=list("ABC"),
    index=["Tim","Tom"])
df2=pd.DataFrame(
    np.arange(9).reshape(3,3),
    columns=list("ACD"),
    index=["Tim","Kate","Tom"])
df1.add(df2, fill_value=0)
# Out:
#         A    B     C    D
# Kate  3.0  NaN   4.0  5.0
# Tim   0.0  1.0   3.0  2.0
# Tom   9.0  4.0  12.0  8.0

# %%
df1.add(df2, fill_value=1)
# Out:
#         A    B     C    D
# Kate  4.0  NaN   5.0  6.0
# Tim   0.0  2.0   3.0  3.0
# Tom   9.0  5.0  12.0  9.0

# %%
df1
# Out:
#      A  B  C
# Tim  0  1  2
# Tom  3  4  5

# %%
1/df1
# Out:
#             A     B    C
# Tim       inf  1.00  0.5
# Tom  0.333333  0.25  0.2

# %%
df1*3
# Out:
#      A   B   C
# Tim  0   3   6
# Tom  9  12  15

# %%
df1.mul(3)
# Out:
#      A   B   C
# Tim  0   3   6
# Tom  9  12  15

# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series(range(5),
             index =[ "e", "d", "a", "b", "c"])
s
# Out:
# e    0
# d    1
# a    2
# b    3
# c    4
# dtype: int64

# %%
s.sort_index()
# Out:
# a    2
# b    3
# c    4
# d    1
# e    0
# dtype: int64

# %%
df=pd.DataFrame(
    np.arange(12).reshape(3,4),
    index=["two","one","three"],
    columns=["d","a","b","c"])
df
# Out:
#        d  a   b   c
# two    0  1   2   3
# one    4  5   6   7
# three  8  9  10  11

# %%
df.sort_index()
# Out:
#        d  a   b   c
# one    4  5   6   7
# three  8  9  10  11
# two    0  1   2   3

# %%
df.sort_index(axis =1)
# Out:
#        a   b   c  d
# two    1   2   3  0
# one    5   6   7  4
# three  9  10  11  8

# %%
df.sort_index(axis =1, ascending = False)
# Out:
#        d   c   b  a
# two    0   3   2  1
# one    4   7   6  5
# three  8  11  10  9

# %%
s2=pd.Series([5,np.nan,3,-1,9])
s2
# Out:
# 0    5.0
# 1    NaN
# 2    3.0
# 3   -1.0
# 4    9.0
# dtype: float64

# %%
s2.sort_values()
# Out:
# 3   -1.0
# 2    3.0
# 0    5.0
# 4    9.0
# 1    NaN
# dtype: float64

# %%
Rk = pd.read_csv('cardekho_dataset.csv')
Rk
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# ...

# %%
Rk.selling_price.mean()
# Out:
# 774971.1164103562

# %%
Rk.brand.unique()
# Out:
# array(['Maruti', 'Hyundai', 'Ford', 'Renault', 'Mini', 'Mercedes-Benz',
#        'Toyota', 'Volkswagen', 'Honda', 'Mahindra', 'Datsun', 'Tata',
#        'Kia', 'BMW', 'Audi', 'Land Rover', 'Jaguar', 'MG', 'Isuzu',
#        'Porsche', 'Skoda', 'Volvo', 'Lexus', 'Jeep', 'Maserati',
#        'Bentley', 'Nissan', 'ISUZU', 'Ferrari', 'Mercedes-AMG',
#        'Rolls-Royce', 'Force'], dtype=object)

# %%
Rk.car_name.unique()
# Out:
# array(['Maruti Alto', 'Hyundai Grand', 'Hyundai i20', 'Ford Ecosport',
#        'Maruti Wagon R', 'Hyundai i10', 'Hyundai Venue', 'Maruti Swift',
#        'Hyundai Verna', 'Renault Duster', 'Mini Cooper', 'Maruti Ciaz',
#        'Mercedes-Benz C-Class', 'Toyota Innova', 'Maruti Baleno',
#        'Maruti Swift Dzire', 'Volkswagen Vento', 'Hyundai Creta',
#        'Honda City', 'Mahindra Bolero', 'Toyota Fortuner', 'Renault KWID',
#        'Honda Amaze', 'Hyundai Santro', 'Mahindra XUV500',
#        'Mahindra KUV100', 'Maruti Ignis', 'Datsun RediGO',
#        'Mahindra Scorpio', 'Mahindra Marazzo', 'Ford Aspire', 'Ford Figo',
#        'Maruti Vitara', 'Tata Tiago', 'Volkswagen Polo', 'Kia Seltos',
#        'Maruti Celerio', 'Datsun GO', 'BMW 5', 'Honda CR-V',
#        'Ford Endeavour', 'Mahindra KUV', 'Honda Jazz', 'BMW 3', 'Audi A4',
#        'Tata Tigor', 'Maruti Ertiga', 'Tata Safari', 'Mahindra Thar',
#        'Tata Hexa', 'Land Rover Rover', 'Maruti Eeco', 'Audi A6',
# ...

# %%
Rk.sort_values(by = "vehicle_age")
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 5078         6451     Maruti Ignis    Maruti     Ignis            0
# 12157       15420  Maruti S-Presso    Maruti  S-Presso            0
# 10315       13164            BMW 5       BMW         5            0
# 11486       14576            BMW 5       BMW         5            0
# 7789         9985     Mahindra KUV  Mahindra       KUV            0
# ...           ...              ...       ...       ...          ...
# 7607         9731   Maruti Wagon R    Maruti   Wagon R           21
# 8146        10457   Maruti Wagon R    Maruti   Wagon R           21
# 14317       18154       Honda City     Honda      City           22
# 15329       19439            BMW 3       BMW         3           25
# 2596         3307      Maruti Alto    Maruti      Alto           29
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 5078        5000  Individual    Petrol            Manual    20.89    1197
# ...

# %%
Rk.sort_values(by = ["vehicle_age", "km_driven", "mileage"])
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 10315       13164            BMW 5       BMW         5            0
# 11486       14576            BMW 5       BMW         5            0
# 5078         6451     Maruti Ignis    Maruti     Ignis            0
# 12157       15420  Maruti S-Presso    Maruti  S-Presso            0
# 7789         9985     Mahindra KUV  Mahindra       KUV            0
# ...           ...              ...       ...       ...          ...
# 6660         8501   Maruti Wagon R    Maruti   Wagon R           21
# 8146        10457   Maruti Wagon R    Maruti   Wagon R           21
# 14317       18154       Honda City     Honda      City           22
# 15329       19439            BMW 3       BMW         3           25
# 2596         3307      Maruti Alto    Maruti      Alto           29
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 10315       2000      Dealer    Diesel         Automatic    22.48    1995
# ...

# %%
Rk.head(10)
# Out:
#    Unnamed: 0        car_name    brand     model  vehicle_age  km_driven  \
# 0           0     Maruti Alto   Maruti      Alto            9     120000
# 1           1   Hyundai Grand  Hyundai     Grand            5      20000
# 2           2     Hyundai i20  Hyundai       i20           11      60000
# 3           3     Maruti Alto   Maruti      Alto            9      37000
# 4           4   Ford Ecosport     Ford  Ecosport            6      30000
# 5           5  Maruti Wagon R   Maruti   Wagon R            8      35000
# 6           6     Hyundai i10  Hyundai       i10            8      40000
# 7           7  Maruti Wagon R   Maruti   Wagon R            3      17512
# 8           8   Hyundai Venue  Hyundai     Venue            2      20000
# 9          12    Maruti Swift   Maruti     Swift            4      28321
#
#   seller_type fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0  Individual    Petrol            Manual    19.70     796      46.30      5
# ...

# %%
Rk.tail(10)
# Out:
#        Unnamed: 0         car_name     brand   model  vehicle_age  km_driven  \
# 15401       19531     Maruti Swift    Maruti   Swift            3      25000
# 15402       19533      Honda Amaze     Honda   Amaze            6      28000
# 15403       19534     Renault KWID   Renault    KWID            2       2700
# 15404       19535    Maruti Ertiga    Maruti  Ertiga            5      56829
# 15405       19536    Hyundai Grand   Hyundai   Grand            5       9229
# 15406       19537      Hyundai i10   Hyundai     i10            9      10723
# 15407       19540    Maruti Ertiga    Maruti  Ertiga            2      18000
# 15408       19541      Skoda Rapid     Skoda   Rapid            6      67000
# 15409       19542  Mahindra XUV500  Mahindra  XUV500            5    3800000
# 15410       19543       Honda City     Honda    City            2      13000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# ...

# %%
Rk.selling_price*3
# Out:
# 0         360000
# 1        1650000
# 2         645000
# 3         678000
# 4        1710000
#           ...
# 15406     750000
# 15407    2775000
# 15408    1275000
# 15409    3675000
# 15410    3600000
# Name: selling_price, Length: 15411, dtype: int64
