# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
games = pd.read_csv('vgsalesGlobale.csv')
games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
games.head(2)
# Out:
#    Rank               Name Platform    Year     Genre Publisher  NA_Sales  \
# 0     1         Wii Sports      Wii  2006.0    Sports  Nintendo     41.49
# 1     2  Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24

# %%
games.head(5)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
games.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
games.Genre
# Out:
# 0              Sports
# 1            Platform
# 2              Racing
# 3              Sports
# 4        Role-Playing
#              ...
# 16593        Platform
# 16594         Shooter
# 16595          Racing
# 16596          Puzzle
# 16597        Platform
# Name: Genre, Length: 16598, dtype: object

# %%
games.Genre.value_counts()
# Out:
# Genre
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: count, dtype: int64

# %%
games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
import pandas as pd

# %%
games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
games.head(5)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
games.head(6)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                    Tetris       GB  1989.0        Puzzle  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37
# 5     23.20      2.26      4.22         0.58         30.26

# %%
games.tail(3)
# Out:
#         Rank                                              Name Platform  \
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16595  2008.0    Racing  Activision      0.00      0.00       0.0
# 16596  2010.0    Puzzle    7G//AMES      0.00      0.01       0.0
# 16597  2003.0  Platform     Wanadoo      0.01      0.00       0.0
#
#        Other_Sales  Global_Sales
# 16595          0.0          0.01
# 16596          0.0          0.01
# 16597          0.0          0.01

# %%
games.Genre
# Out:
# 0              Sports
# 1            Platform
# 2              Racing
# 3              Sports
# 4        Role-Playing
#              ...
# 16593        Platform
# 16594         Shooter
# 16595          Racing
# 16596          Puzzle
# 16597        Platform
# Name: Genre, Length: 16598, dtype: object

# %%
games.Genre.describe()
# Out:
# count      16598
# unique        12
# top       Action
# freq        3316
# Name: Genre, dtype: object

# %%
games.JP_Sales.describe()
# Out:
# count    16598.000000
# mean         0.077782
# std          0.309291
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.040000
# max         10.220000
# Name: JP_Sales, dtype: float64

# %%
games.shape
# Out:
# (16598, 11)

# %%
games.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
games.Genre.value_counts()
# Out:
# Genre
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: count, dtype: int64

# %%
games.Genre.value_counts().sum()
# Out:
# 16598

# %%
games.Genre.value_counts(normalize=True)
# Out:
# Genre
# Action          0.199783
# Sports          0.141342
# Misc            0.104772
# Role-Playing    0.089649
# Shooter         0.078925
# Adventure       0.077479
# Racing          0.075250
# Platform        0.053380
# Simulation      0.052235
# Fighting        0.051090
# Strategy        0.041029
# Puzzle          0.035064
# Name: proportion, dtype: float64

# %%
Rohit = pd.read_csv('data1.csv')

# %%
Rohit
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 22184    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 22185    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 22186    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 22187    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 22188    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
Rohit.head(2)
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# 0    Filled jobs  Agriculture, Forestry and Fishing         Actual
# 1    Filled jobs  Agriculture, Forestry and Fishing         Actual
#
#    Series_title_4  Series_title_5
# 0             NaN             NaN
# 1             NaN             NaN

# %%
Rohit.head(4)
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2      BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3      BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# 0    Filled jobs  Agriculture, Forestry and Fishing         Actual
# 1    Filled jobs  Agriculture, Forestry and Fishing         Actual
# ...

# %%
Rohit.head(6)
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2      BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3      BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4      BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
# 5      BDCQ.SEA1AA  2012.09     79261.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
# ...

# %%
Rohit.tail(2)
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 22187    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 22188    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 22187          0  Business Data Collection - BDC
# 22188          0  Business Data Collection - BDC
#
#                                               Group  \
# 22187  Territorial authority by employment variable
# 22188  Territorial authority by employment variable
#
#                                Series_title_1  \
# 22187  Filled jobs (workplace location based)
# 22188  Filled jobs (workplace location based)
#
#                            Series_title_2 Series_title_3  Series_title_4  \
# 22187  Area Outside Territorial Authority         Actual             NaN
# 22188  Area Outside Territorial Authority         Actual             NaN
#
#        Series_title_5
# 22187             NaN
# 22188             NaN

# %%
Rohit.tail(9)
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 22180    BDCQ.SEE3999A  2016.06         NaN          Y      C  Number
# 22181    BDCQ.SEE3999A  2016.09         NaN          Y      C  Number
# 22182    BDCQ.SEE3999A  2016.12         NaN          Y      C  Number
# 22183    BDCQ.SEE3999A  2017.03         NaN          Y      C  Number
# 22184    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 22185    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 22186    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 22187    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 22188    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 22180          0  Business Data Collection - BDC
# 22181          0  Business Data Collection - BDC
# 22182          0  Business Data Collection - BDC
# 22183          0  Business Data Collection - BDC
# ...

# %%
Rohit.dtypes
# Out:
# Series_reference     object
# Period              float64
# Data_value          float64
# Suppressed           object
# STATUS               object
# UNITS                object
# Magnitude             int64
# Subject              object
# Group                object
# Series_title_1       object
# Series_title_2       object
# Series_title_3       object
# Series_title_4      float64
# Series_title_5      float64
# dtype: object

# %%
Rohit.Series_title_4
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 22184   NaN
# 22185   NaN
# 22186   NaN
# 22187   NaN
# 22188   NaN
# Name: Series_title_4, Length: 22189, dtype: float64

# %%
Rohit.Period
# Out:
# 0        2011.06
# 1        2011.09
# 2        2011.12
# 3        2012.03
# 4        2012.06
#           ...
# 22184    2017.06
# 22185    2017.09
# 22186    2017.12
# 22187    2018.03
# 22188    2018.06
# Name: Period, Length: 22189, dtype: float64

# %%
Rohit.Period.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        2011.06
# 1        2011.09
# 2        2011.12
# 3        2012.03
# 4        2012.06
#           ...
# 22184    2017.06
# 22185    2017.09
# 22186    2017.12
# 22187    2018.03
# 22188    2018.06
# Name: Period, Length: 22189, dtype: float64>

# %%
Rohit.Series_title_4.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 22184   NaN
# 22185   NaN
# 22186   NaN
# 22187   NaN
# 22188   NaN
# Name: Series_title_4, Length: 22189, dtype: float64>

# %%
Rohit.describe()
# Out:
#              Period    Data_value     Magnitude  Series_title_4  \
# count  22189.000000  1.935000e+04  22189.000000             0.0
# mean    2016.896049  7.222688e+04      2.327910             NaN
# std        3.557176  2.089239e+05      2.923813             NaN
# min     2011.060000  1.187001e+00      0.000000             NaN
# 25%     2014.060000  1.862571e+03      0.000000             NaN
# 50%     2017.060000  1.407000e+04      0.000000             NaN
# 75%     2020.060000  6.016300e+04      6.000000             NaN
# max     2023.090000  2.295859e+06      6.000000             NaN
#
#        Series_title_5
# count             0.0
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN

# %%
Rohit.shape
# Out:
# (22189, 14)

# %%
Rohit.Period.describe()
# Out:
# count    22189.000000
# mean      2016.896049
# std          3.557176
# min       2011.060000
# 25%       2014.060000
# 50%       2017.060000
# 75%       2020.060000
# max       2023.090000
# Name: Period, dtype: float64

# %%
Rohit.Period.value_counts().sum()
# Out:
# 22189

# %%
Rohit.Period.value_counts(normalize=True)
# Out:
# Period
# 2012.09    0.020821
# 2011.06    0.020731
# 2015.06    0.020731
# 2018.06    0.020731
# 2018.03    0.020731
# 2017.12    0.020731
# 2011.09    0.020731
# 2017.06    0.020731
# 2017.03    0.020731
# 2016.12    0.020731
# 2016.09    0.020731
# 2016.06    0.020731
# 2016.03    0.020731
# 2015.12    0.020731
# 2015.09    0.020731
# 2017.09    0.020731
# 2015.03    0.020731
# 2013.06    0.020731
# 2011.12    0.020731
# 2012.03    0.020731
# 2012.06    0.020731
# 2013.03    0.020731
# 2012.12    0.020731
# 2013.09    0.020731
# 2013.12    0.020731
# 2014.03    0.020731
# 2014.06    0.020731
# 2014.09    0.020731
# 2014.12    0.020731
# 2019.12    0.020686
# 2020.12    0.020686
# 2020.09    0.020686
# 2020.06    0.020686
# 2020.03    0.020686
# 2019.09    0.020686
# 2019.06    0.020686
# 2019.03    0.020686
# 2018.12    0.020686
# 2018.09    0.020686
# 2021.03    0.017441
# 2021.06    0.017441
# 2021.09    0.017441
# 2021.12    0.017441
# 2022.03    0.017441
# 2022.06    0.017441
# ...

# %%
games.Genre.unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
games.Genre.unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
games.Genre.nunique()
# Out:
# 12

# %%
Rohit
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 22184    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 22185    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 22186    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 22187    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 22188    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
pd.crosstab(games.Name, games.Year)
# Out:
# Year                                     1980.0  1981.0  1982.0  1983.0  \
# Name
# '98 Koshien                                   0       0       0       0
# .hack//G.U. Vol.1//Rebirth                    0       0       0       0
# .hack//G.U. Vol.2//Reminisce                  0       0       0       0
# .hack//G.U. Vol.2//Reminisce (jp sales)       0       0       0       0
# .hack//G.U. Vol.3//Redemption                 0       0       0       0
# ...                                         ...     ...     ...     ...
# thinkSMART FAMILY!                            0       0       0       0
# thinkSMART: Chess for Kids                    0       0       0       0
# uDraw Studio                                  0       0       0       0
# uDraw Studio: Instant Artist                  0       0       0       0
# ¡Shin Chan Flipa en colores!                  0       0       0       0
#
# Year                                     1984.0  1985.0  1986.0  1987.0  \
# Name
# ...

# %%
pd.crosstab(games.Publisher, games.Year)
# Out:
# Year                          1980.0  1981.0  1982.0  1983.0  1984.0  1985.0  \
# Publisher
# 10TACLE Studios                    0       0       0       0       0       0
# 1C Company                         0       0       0       0       0       0
# 20th Century Fox Video Games       0       3       2       0       0       0
# 2D Boy                             0       0       0       0       0       0
# 3DO                                0       0       0       0       0       0
# ...                              ...     ...     ...     ...     ...     ...
# id Software                        0       0       0       0       0       0
# imageepoch Inc.                    0       0       0       0       0       0
# inXile Entertainment               0       0       0       0       0       0
# mixi, Inc                          0       0       0       0       0       0
# responDESIGN                       0       0       0       0       0       0
#
# ...

# %%
games.Year.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
games.Genre
# Out:
# 0              Sports
# 1            Platform
# 2              Racing
# 3              Sports
# 4        Role-Playing
#              ...
# 16593        Platform
# 16594         Shooter
# 16595          Racing
# 16596          Puzzle
# 16597        Platform
# Name: Genre, Length: 16598, dtype: object

# %%
games['Genre']
# Out:
# 0              Sports
# 1            Platform
# 2              Racing
# 3              Sports
# 4        Role-Playing
#              ...
# 16593        Platform
# 16594         Shooter
# 16595          Racing
# 16596          Puzzle
# 16597        Platform
# Name: Genre, Length: 16598, dtype: object

# %%
games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
games.rename(index={0:"one", 1:"two", 2:"three", 3:"four"})
# Out:
#         Rank                                              Name Platform  \
# one        1                                        Wii Sports      Wii
# two        2                                 Super Mario Bros.      NES
# three      3                                    Mario Kart Wii      Wii
# four       4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 games.loc["one", "two", "three", "four":"Platform"]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1283, in _LocIndexer._getitem_tuple(self, tup)
#    1280     return self._getitem_lowerdim(tup)
#    1282 # no multi-index, so validate all of the indexers
# -> 1283 tup = self._validate_tuple_indexer(tup)
#    1285 # ugly hack for GH #836
#    1286 if self._multi_take_opportunity(tup):
#
# ...
